# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# Ignore harmless warnings 

import warnings 
warnings.filterwarnings("ignore")

# Set to display all the columns in dataset

pd.set_option("display.max_columns", None)

# Import psql to run queries 

import pandasql as psql

# %%
credit_card = pd.read_csv(r"C:\Users\HP\Downloads\archive.zip",header=0)

credit_card = credit_card.copy()

credit_card.head()
# Out:
#    Applicant_ID Applicant_Gender  Owned_Car  Owned_Realty  Total_Children  \
# 0       5008806          M                1             1               0
# 1       5008808          F                0             1               0
# 2       5008809          F                0             1               0
# 3       5008810          F                0             1               0
# 4       5008811          F                0             1               0
#
#    Total_Income                                        Income_Type  \
# 0        112500  Working                                       ...
# 1        270000  Commercial associate                          ...
# 2        270000  Commercial associate                          ...
# 3        270000  Commercial associate                          ...
# 4        270000  Commercial associate                          ...
#
#                                       Education_Type  \
# 0  Secondary / secondary special                 ...
# ...

# %%
credit_card.tail()
# Out:
#        Applicant_ID Applicant_Gender  Owned_Car  Owned_Realty  Total_Children  \
# 25123       5150482          F                1             1               1
# 25124       5150483          F                1             1               1
# 25125       5150484          F                1             1               1
# 25126       5150485          F                1             1               1
# 25127       5150487          M                1             0               0
#
#        Total_Income                                        Income_Type  \
# 25123        157500  Working                                       ...
# 25124        157500  Working                                       ...
# 25125        157500  Working                                       ...
# 25126        157500  Working                                       ...
# 25127        202500  Working                                       ...
#
#                                           Education_Type  \
# ...

# %%
credit_card.sample(10)
# Out:
#        Applicant_ID Applicant_Gender  Owned_Car  Owned_Realty  Total_Children  \
# 17528       5111099          F                1             1               2
# 25059       5150242          M                0             0               0
# 19311       5116438          F                1             1               0
# 12195       5069311          F                0             1               0
# 10145       5062462          F                0             1               0
# 24290       5148858          M                0             0               2
# 5744        5038914          F                0             1               1
# 11964       5068920          F                0             1               1
# 8240        5052966          M                1             1               0
# 15279       5093248          F                0             1               0
#
#        Total_Income                                        Income_Type  \
# ...

# %%
credit_card.shape
# Out:
# (25128, 21)

# %%
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25128 entries, 0 to 25127
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Applicant_ID          25128 non-null  int64
#  1   Applicant_Gender      25128 non-null  object
#  2   Owned_Car             25128 non-null  int64
#  3   Owned_Realty          25128 non-null  int64
#  4   Total_Children        25128 non-null  int64
#  5   Total_Income          25128 non-null  int64
#  6   Income_Type           25128 non-null  object
#  7   Education_Type        25128 non-null  object
#  8   Family_Status         25128 non-null  object
#  9   Housing_Type          25128 non-null  object
#  10  Owned_Mobile_Phone    25128 non-null  int64
#  11  Owned_Work_Phone      25128 non-null  int64
#  12  Owned_Phone           25128 non-null  int64
#  13  Owned_Email           25128 non-null  int64
#  14  Job_Title             25128 non-null  object
# ...

# %%
credit_card.describe().T
# Out:
#                         count          mean            std        min  \
# Applicant_ID          25128.0  5.078835e+06   41943.777736  5008806.0
# Owned_Car             25128.0  4.183779e-01       0.493303        0.0
# Owned_Realty          25128.0  6.549268e-01       0.475402        0.0
# Total_Children        25128.0  5.094715e-01       0.762937        0.0
# Total_Income          25128.0  1.948365e+05  104521.123300    27000.0
# Owned_Mobile_Phone    25128.0  1.000000e+00       0.000000        1.0
# Owned_Work_Phone      25128.0  2.737584e-01       0.445895        0.0
# Owned_Phone           25128.0  2.927412e-01       0.455030        0.0
# Owned_Email           25128.0  1.006845e-01       0.300916        0.0
# Total_Family_Members  25128.0  2.291309e+00       0.928871        1.0
# Applicant_Age         25128.0  4.099550e+01       9.552832       21.0
# Years_of_Working      25128.0  7.690903e+00       6.415007        1.0
# ...

# %%
credit_card.columns
# Out:
# Index(['Applicant_ID', 'Applicant_Gender', 'Owned_Car', 'Owned_Realty',
#        'Total_Children', 'Total_Income', 'Income_Type', 'Education_Type',
#        'Family_Status', 'Housing_Type', 'Owned_Mobile_Phone',
#        'Owned_Work_Phone', 'Owned_Phone', 'Owned_Email', 'Job_Title',
#        'Total_Family_Members', 'Applicant_Age', 'Years_of_Working',
#        'Total_Bad_Debt', 'Total_Good_Debt', 'Status'],
#       dtype='object')

# %%
credit_card.isnull().sum()
# Out:
# Applicant_ID            0
# Applicant_Gender        0
# Owned_Car               0
# Owned_Realty            0
# Total_Children          0
# Total_Income            0
# Income_Type             0
# Education_Type          0
# Family_Status           0
# Housing_Type            0
# Owned_Mobile_Phone      0
# Owned_Work_Phone        0
# Owned_Phone             0
# Owned_Email             0
# Job_Title               0
# Total_Family_Members    0
# Applicant_Age           0
# Years_of_Working        0
# Total_Bad_Debt          0
# Total_Good_Debt         0
# Status                  0
# dtype: int64

# %%
credit_card.nunique()
# Out:
# Applicant_ID            25128
# Applicant_Gender            2
# Owned_Car                   2
# Owned_Realty                2
# Total_Children              6
# Total_Income              195
# Income_Type                 5
# Education_Type              5
# Family_Status               5
# Housing_Type                6
# Owned_Mobile_Phone          1
# Owned_Work_Phone            2
# Owned_Phone                 2
# Owned_Email                 2
# Job_Title                  18
# Total_Family_Members        7
# Applicant_Age              48
# Years_of_Working           43
# Total_Bad_Debt             33
# Total_Good_Debt            61
# Status                      2
# dtype: int64

# %%
credit_card.duplicated().sum()
# Out:
# 0

# %%
average_income=credit_card["Total_Income"].mean()
average_income
# Out:
# 194836.49856733525

# %%
gender_income=credit_card.groupby("Applicant_Gender")["Total_Income"].mean()
gender_income
# Out:
# Applicant_Gender
# F          179176.213349
# M          220594.132197
# Name: Total_Income, dtype: float64

# %%
#to get decending order
gender_income.sort_values(ascending=False)
# Out:
# Applicant_Gender
# M          220594.132197
# F          179176.213349
# Name: Total_Income, dtype: float64

# %%
sns.barplot(x=gender_income.index ,y=gender_income.values)
plt.title("Average income by gender")
plt.xlabel("Genders")
plt.ylabel("Money")
plt.show()

# %%
label_counts= credit_card["Status"].value_counts()
label_counts
# Out:
# Status
# 1    25007
# 0      121
# Name: count, dtype: int64

# %%
plt.pie(label_counts,labels=["Credit Approved","Credit Rejected"],autopct="%1.1f")
plt.title("Credit Card Approval Status")
plt.show()

# %%
credit_card.groupby("Income_Type")["Total_Income"].mean()
# Out:
# Income_Type
# Commercial associate                                  218450.593732
# Pensioner                                             257538.461538
# State servant                                         205066.710300
# Student                                               159300.000000
# Working                                               182546.706967
# Name: Total_Income, dtype: float64

# %%
credit_card.groupby("Family_Status")["Years_of_Working"].mean()
# Out:
# Family_Status
# Civil marriage                                        6.928270
# Married                                               7.830582
# Separated                                             8.336749
# Single / not married                                  6.891405
# Widow                                                 9.396552
# Name: Years_of_Working, dtype: float64

# %%
credit_card.groupby("Housing_Type")["Total_Family_Members"].mean()
# Out:
# Housing_Type
# Co-op apartment                                       2.342105
# House / apartment                                     2.297429
# Municipal apartment                                   2.219212
# Office apartment                                      2.507538
# Rented apartment                                      1.906606
# With parents                                          2.320280
# Name: Total_Family_Members, dtype: float64

# %%
credit_card.groupby("Owned_Realty")["Total_Income"].mean()
# Out:
# Owned_Realty
# 0    189867.857917
# 1    197454.416965
# Name: Total_Income, dtype: float64

# %%
credit_card.groupby("Education_Type")["Owned_Mobile_Phone"].mean()
# Out:
# Education_Type
# Academic degree                                       1.0
# Higher education                                      1.0
# Incomplete higher                                     1.0
# Lower secondary                                       1.0
# Secondary / secondary special                         1.0
# Name: Owned_Mobile_Phone, dtype: float64

# %%
credit_card["Owned_Mobile_Phone"].value_counts()
# Out:
# Owned_Mobile_Phone
# 1    25128
# Name: count, dtype: int64

# %%
credit_card.groupby("Total_Children")["Total_Income"].sum()
# Out:
# Total_Children
# 0    3104790925
# 1    1205185811
# 2     515259900
# 3      57537900
# 4       9828000
# 5       3249000
# Name: Total_Income, dtype: int64

# %%
#sns.boxplot(x = "Applicant_Gender",y = "Total_Income",credit_card=credit_card)
#plt.title("annual income variation by marital status")
#plt.show()

# %%
credit_card.groupby("Family_Status")["Total_Family_Members"].sum().plot(kind="pie",autopct="%1.1f%%")
plt.title("Family members distribution by marital status")
plt.show()

# %%
credit_card.boxplot(column = "Total_Income", by = "Education_Type")
plt.title("annual income variation by educaton level")
plt.show()

# %%
credit_card=credit_card[["Owned_Car","Owned_Realty","Total_Income","Education_Type","Status"]]

# %%
credit_card
# Out:
#        Owned_Car  Owned_Realty  Total_Income  \
# 0              1             1        112500
# 1              0             1        270000
# 2              0             1        270000
# 3              0             1        270000
# 4              0             1        270000
# ...          ...           ...           ...
# 25123          1             1        157500
# 25124          1             1        157500
# 25125          1             1        157500
# 25126          1             1        157500
# 25127          1             0        202500
#
#                                           Education_Type  Status
# 0      Secondary / secondary special                 ...       1
# 1      Secondary / secondary special                 ...       1
# 2      Secondary / secondary special                 ...       1
# 3      Secondary / secondary special                 ...       1
# 4      Secondary / secondary special                 ...       1
# ...

# %%
from sklearn import preprocessing
labelencoder= preprocessing.LabelEncoder()

# %%
credit_card["Owned_Car"]=labelencoder.fit_transform(credit_card["Owned_Car"])
credit_card["Owned_Realty"]=labelencoder.fit_transform(credit_card["Owned_Realty"])
credit_card["Education_Type"]=labelencoder.fit_transform(credit_card["Education_Type"])

# %%
credit_card
# Out:
#        Owned_Car  Owned_Realty  Total_Income  Education_Type  Status
# 0              1             1        112500               4       1
# 1              0             1        270000               4       1
# 2              0             1        270000               4       1
# 3              0             1        270000               4       1
# 4              0             1        270000               4       1
# ...          ...           ...           ...             ...     ...
# 25123          1             1        157500               4       1
# 25124          1             1        157500               4       1
# 25125          1             1        157500               4       1
# 25126          1             1        157500               4       1
# 25127          1             0        202500               4       1
#
# [25128 rows x 5 columns]

# %%
x = credit_card.iloc[:, : -1]

# %%
y = credit_card.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test =  train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_x_train = scaler.fit_transform(x_train)
scaled_x_test = scaler.fit_transform(x_test)

# %%
from sklearn.metrics import accuracy_score
def modelperformance(predictions):
    print("Accuracy score on model is{}".format(accuracy_score(y_test,predictions)))

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()
log_model.fit(scaled_x_train,y_train)
# Out:
# LogisticRegression()

# %%
log_predictions = log_model.predict(scaled_x_test)

# %%
modelperformance(log_predictions)
# Out:
# Accuracy score on model is0.9974134500596896

# %%
# Identify the independent and Target (dependent) variables

IndepVar = []
for col in credit_card.columns:
    if col != 'Status':
        IndepVar.append(col)

TargetVar = 'Status'

x = credit_card[IndepVar]
y = credit_card[TargetVar]

# %%
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Display the shape for train & test data

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((17589, 4), (7539, 4), (17589,), (7539,))

# %%
from sklearn.preprocessing import MinMaxScaler

mmscaler = MinMaxScaler(feature_range=(0, 1))

x_train = mmscaler.fit_transform(x_train)
x_train = pd.DataFrame(x_train)

x_test= mmscaler.fit_transform(x_test)
x_test = pd.DataFrame(x_test)

# %%
y_test.head()
# Out:
# 13396    1
# 5324     1
# 13640    1
# 5070     1
# 17645    1
# Name: Status, dtype: int64

# %%
x_train=np.array(x_train)
x_test=np.array(x_test)

# %% [markdown]
# # KNN

# %%
KNN_Results=pd.read_csv(r"C:\Users\HP\Downloads\knnresults.csv",header=0)
KNN_Results.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, KNN K Value, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %%
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import sklearn.metrics as metrics

from sklearn.metrics import roc_curve, roc_auc_score

accuracy = []

for a in range(1, 21, 1):
    
    k = a
    
    # Build the model
    
    ModelKNN = KNeighborsClassifier(n_neighbors=k)
    
    # Train the model
    
    ModelKNN.fit(x_train, y_train)
    
    # Predict the model
    
    y_pred = ModelKNN.predict(x_test)
    y_pred_prob = ModelKNN.predict_proba(x_test)
    
    print('KNN_K_value = ', a)
    
    # Print the model name
    
    print('Model Name: ', ModelKNN)
    
    # confusion matrix in sklearn
    
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report
    
    # actual values
    
    actual = y_test
    
    # predicted values
    
    predicted = y_pred
    
    # confusion matrix
    
    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)
    
    # outcome values order in sklearn
    
    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)
    
    # classification report for precision, recall f1-score and accuracy
    
    C_Report = classification_report(actual,predicted,labels=[1,0])
    
    print('Classification report : \n', C_Report)
    
    # calculating the metrics
    
    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);
    
    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);
    
    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
    # A model with a score of +1 is a perfect model and -1 is a poor model
    
    from math import sqrt
    
    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)
    
    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)
    
    # Area under ROC curve 
    
    from sklearn.metrics import roc_curve, roc_auc_score
    
    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))
    
    # ROC Curve
    
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, ModelKNN.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    #plt.savefig('Log_ROC')
    plt.show()
    #------------------------------------------------------------------------------
    new_row = {'Model Name' : ModelKNN,
               'KNN K Value' : a,
               'True_Positive' : tp,
               'False_Negative' : fn,
               'False_Positive' : fp,
               'True_Negative' : tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    KNN_Results = KNN_Results._append(new_row, ignore_index=True)
    #------KNN_Results------------------------------------------------------------------------
# Out:
# KNN_K_value =  1
# Model Name:  KNeighborsClassifier(n_neighbors=1)
# Confusion matrix :
#  [[7485   11]
#  [  42    1]]
# Outcome values :
#  7485 11 42 1
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      7496
#            0       0.08      0.02      0.04        43
#
#     accuracy                           0.99      7539
#    macro avg       0.54      0.51      0.52      7539
# weighted avg       0.99      0.99      0.99      7539
#
# Accuracy : 99.3 %
# Precision : 99.4 %
# Recall : 99.9 %
# F1 Score : 0.996
# Specificity or True Negative Rate : 2.3 %
# Balanced Accuracy : 51.1 %
# MCC : 0.041
# roc_auc_score: 0.511
# KNN_K_value =  2
# Model Name:  KNeighborsClassifier(n_neighbors=2)
# Confusion matrix :
#  [[7474   22]
#  [  42    1]]
# Outcome values :
#  7474 22 42 1
# Classification report :
#                precision    recall  f1-score   support
#
# ...

# %%
KNN_Results.head(20)
# Out:
#                               Model Name KNN K Value  Accuracy  Precision  \
# 0    KNeighborsClassifier(n_neighbors=1)           1     0.993      0.994
# 1    KNeighborsClassifier(n_neighbors=2)           2     0.992      0.994
# 2    KNeighborsClassifier(n_neighbors=3)           3     0.994      0.994
# 3    KNeighborsClassifier(n_neighbors=4)           4     0.994      0.994
# 4                 KNeighborsClassifier()           5     0.994      0.994
# 5    KNeighborsClassifier(n_neighbors=6)           6     0.994      0.994
# 6    KNeighborsClassifier(n_neighbors=7)           7     0.994      0.994
# 7    KNeighborsClassifier(n_neighbors=8)           8     0.994      0.994
# 8    KNeighborsClassifier(n_neighbors=9)           9     0.994      0.994
# 9   KNeighborsClassifier(n_neighbors=10)          10     0.994      0.994
# 10  KNeighborsClassifier(n_neighbors=11)          11     0.994      0.994
# 11  KNeighborsClassifier(n_neighbors=12)          12     0.994      0.994
# ...

# %% [markdown]
# # Desicion tree

# %%
# To build the 'Logistic Regression' model with random sampling

from sklearn.tree import DecisionTreeClassifier

# Create an object for model

ModelDT = DecisionTreeClassifier()
#ModelLR = LogisticRegression(penalty='l2', dual=False, tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, 
#                             class_weight=None, random_state=None, solver='lbfgs', max_iter=100, multi_class='auto', 
#                             verbose=0, warm_start=False, n_jobs=None, l1_ratio=None)

# Train the model train data 

ModelDT.fit(x_train, y_train)

# Predict the model with test da

y_pred = ModelDT.predict(x_test)
y_pred_prob = ModelDT.predict_proba(x_test)

# %%
# 'Confusion matrix' and 'classification report' in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Actual values

actual = y_test

# Predicted values

predicted = y_pred

# Confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0], sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# Outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# Classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# Calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
    
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%')
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
model_roc_auc = roc_auc_score(actual, predicted)
fpr, tpr, thresholds = roc_curve(actual, ModelDT.predict_proba(x_test)[:,1])
plt.figure()
#----------------------------------------------------
plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show() 
print('-----------------------------------------------------------------------------------------------------')
# Out:
# Confusion matrix :
#  [[7491    5]
#  [  42    1]]
# Outcome values :
#  7491 5 42 1
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      7496
#            0       0.17      0.02      0.04        43
#
#     accuracy                           0.99      7539
#    macro avg       0.58      0.51      0.52      7539
# weighted avg       0.99      0.99      0.99      7539
#
# Accuracy : 99.4 %
# Precision : 99.4 %
# Recall : 99.9 %
# F1 Score : 0.997
# Specificity or True Negative Rate : 2.3 %
# Balanced Accuracy : 51.1 %
# MCC : 0.06
# roc_auc_score: 0.511
# -----------------------------------------------------------------------------------------------------

# %%
# Display the Final results 

Results = pd.DataFrame({'Status_A':y_test, 'Status_P':y_pred})

# Merge two Dataframes on index of both the dataframes

ResultsFinal = credit_card.merge(Results, left_index=True, right_index=True)

# Display 10 records randomly

ResultsFinal.sample(10)
# Out:
#        Owned_Car  Owned_Realty  Total_Income  Education_Type  Status  \
# 14774          0             0        225000               4       1
# 6409           1             1        247500               1       1
# 3707           0             1        202500               4       1
# 19047          1             1        180000               4       1
# 18596          0             0        157500               1       1
# 23499          0             0        135000               1       1
# 7304           1             1        112500               4       1
# 22296          1             0        360000               4       1
# 14145          0             0        180000               1       1
# 16536          0             0        135000               4       1
#
#        Exited_A  Exited_P
# 14774         1         1
# 6409          1         1
# 3707          1         1
# 19047         1         1
# 18596         1         1
# 23499         1         1
# ...

# %%
import matplotlib.pyplot as plt
from sklearn import tree

plt.figure(figsize=(20,5))
tree.plot_tree(ModelDT);

# %% [markdown]
# # Logistic Regression

# %%
# To build the 'Logistic Regression' model with random sampling

from sklearn.linear_model import LogisticRegression

# Create an object for model

ModelLR = LogisticRegression()
#ModelLR = LogisticRegression(penalty='l2', dual=False, tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, 
#                             class_weight=None, random_state=None, solver='lbfgs', max_iter=100, multi_class='auto', 
#                             verbose=0, warm_start=False, n_jobs=None, l1_ratio=None)

# Train the model train data 

ModelLR.fit(x_train, y_train)

# Predict the model with test da

y_pred = ModelLR.predict(x_test)
y_pred_prob = ModelLR.predict_proba(x_test)

# %%
# 'Confusion matrix' and 'classification report' in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Actual values

actual = y_test

# Predicted values

predicted = y_pred

# Confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0], sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# Outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# Classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# Calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
    
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%')
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
model_roc_auc = roc_auc_score(actual, predicted)
fpr, tpr, thresholds = roc_curve(actual, ModelLR.predict_proba(x_test)[:,1])
plt.figure()
#----------------------------------------------------
plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show() 
print('-----------------------------------------------------------------------------------------------------')
# Out:
# Confusion matrix :
#  [[7496    0]
#  [  43    0]]
# Outcome values :
#  7496 0 43 0
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      7496
#            0       0.00      0.00      0.00        43
#
#     accuracy                           0.99      7539
#    macro avg       0.50      0.50      0.50      7539
# weighted avg       0.99      0.99      0.99      7539
#
# Accuracy : 99.4 %
# Precision : 99.4 %
# Recall : 100.0 %
# F1 Score : 0.997
# Specificity or True Negative Rate : 0.0 %
# Balanced Accuracy : 50.0 %
# MCC : nan
# roc_auc_score: 0.5
# -----------------------------------------------------------------------------------------------------

# %%
# Display the Final results 

Results = pd.DataFrame({'Status_A':y_test, 'Status_P':y_pred})

# Merge two Dataframes on index of both the dataframes

ResultsFinal = credit_card.merge(Results, left_index=True, right_index=True)

# Display 10 records randomly

ResultsFinal.sample(10)
# Out:
#        Owned_Car  Owned_Realty  Total_Income  Education_Type  Status  \
# 7794           0             0        135000               4       1
# 22738          1             1        157500               4       1
# 10581          1             1        315000               4       1
# 24485          1             1        180000               4       1
# 18976          1             1        234000               4       1
# 10446          0             1        157500               1       1
# 2707           0             1        180000               4       1
# 3396           1             1        180000               2       1
# 7172           0             0        180000               1       1
# 8443           0             1        135000               4       1
#
#        Status_A  Status_P
# 7794          1         1
# 22738         1         1
# 10581         1         1
# 24485         1         1
# 18976         1         1
# 10446         1         1
# ...

# %%
del ResultsFinal['Status_A']

ResultsFinal.sample(10)
# Out:
#        Owned_Car  Owned_Realty  Total_Income  Education_Type  Status  Status_P
# 18804          1             1        166500               4       1         1
# 23683          1             1        157500               4       1         1
# 24287          1             1        261000               4       1         1
# 17597          1             1        180000               4       1         1
# 21120          0             1        112500               4       1         1
# 8246           1             1        360000               4       1         1
# 701            0             1        135000               4       1         1
# 15878          1             0        112500               4       1         1
# 24516          1             1        270000               4       1         1
# 5170           1             0        360000               1       1         1
